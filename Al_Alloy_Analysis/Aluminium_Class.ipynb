# %% [markdown]
# # Tutorial 2 : Difference between Zn- Mg Alluminium Alloy and Si Alluminium Alloy

# %% [markdown]
# # Importing the Useful librararies.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from peakutils import indexes
from  scipy.signal import find_peaks as fp

from bokeh.plotting import figure , show

from bokeh.io import output_notebook
from bokeh.models import LabelSet

output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f5b37b65-2e32-42a5-befb-2e80c99456e2">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Lets Import csv files for Zn-Mg Alluminium Alloy (Alloy 7022)

# %%
Alloy_7022 = pd.read_csv(r'7022.csv', skiprows=0)
Alloy_7022
# Out:
#      Wavelength    Intensity  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0           200  390000000.0         NaN         NaN         NaN         NaN
# 1           201  511000000.0         NaN         NaN         NaN         NaN
# 2           202  607000000.0         NaN         NaN         NaN         NaN
# 3         203.1  661000000.0         NaN         NaN         NaN         NaN
# 4         204.1  655000000.0         NaN         NaN         NaN         NaN
# ...         ...          ...         ...         ...         ...         ...
# 1760     1995.9         60.0         NaN         NaN         NaN         NaN
# 1761     1996.9         58.0         NaN         NaN         NaN         NaN
# 1762       1998         55.8         NaN         NaN         NaN         NaN
# 1763       1999         53.8         NaN         NaN         NaN         NaN
# 1764       2000         51.8         NaN         NaN         NaN         NaN
#
#       Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  \
# 0            NaN         NaN         NaN         NaN  ...          NaN
# 1            NaN         NaN         NaN         NaN  ...          NaN
# 2            NaN         NaN         NaN         NaN  ...          NaN
# 3            NaN         NaN         NaN         NaN  ...          NaN
# 4            NaN         NaN         NaN         NaN  ...          NaN
# ...          ...         ...         ...         ...  ...          ...
# 1760         NaN         NaN         NaN         NaN  ...          NaN
# 1761         NaN         NaN         NaN         NaN  ...          NaN
# 1762         NaN         NaN         NaN         NaN  ...          NaN
# 1763         NaN         NaN         NaN         NaN  ...          NaN
# 1764         NaN         NaN         NaN         NaN  ...          NaN
#
#       Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 1760          NaN          NaN          NaN          NaN          NaN
# 1761          NaN          NaN          NaN          NaN          NaN
# 1762          NaN          NaN          NaN          NaN          NaN
# 1763          NaN          NaN          NaN          NaN          NaN
# 1764          NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0             NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 1760          NaN          NaN          NaN          NaN
# 1761          NaN          NaN          NaN          NaN
# 1762          NaN          NaN          NaN          NaN
# 1763          NaN          NaN          NaN          NaN
# 1764          NaN          NaN          NaN          NaN
#
# [1765 rows x 26 columns]

# %% [markdown]
# # Lets Import csv files for Si Alluminium Alloy (Alloy 4043)

# %%
Alloy_4043 = pd.read_csv(r'4043.csv', skiprows=0)
Alloy_4043
# Out:
#      Wavelength   Intensity  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0           200  12400000.0         NaN         NaN         NaN         NaN
# 1         200.9  16100000.0         NaN         NaN         NaN         NaN
# 2         201.9  19500000.0         NaN         NaN         NaN         NaN
# 3         202.8  21500000.0         NaN         NaN         NaN         NaN
# 4         203.8  22200000.0         NaN         NaN         NaN         NaN
# ...         ...         ...         ...         ...         ...         ...
# 1893     1985.8      1730.0         NaN         NaN         NaN         NaN
# 1894     1986.8      1690.0         NaN         NaN         NaN         NaN
# 1895     1987.7      1640.0         NaN         NaN         NaN         NaN
# 1896     1988.7      1600.0         NaN         NaN         NaN         NaN
# 1897     1989.6      1560.0         NaN         NaN         NaN         NaN
#
#       Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  \
# 0            NaN         NaN         NaN         NaN  ...          NaN
# 1            NaN         NaN         NaN         NaN  ...          NaN
# 2            NaN         NaN         NaN         NaN  ...          NaN
# 3            NaN         NaN         NaN         NaN  ...          NaN
# 4            NaN         NaN         NaN         NaN  ...          NaN
# ...          ...         ...         ...         ...  ...          ...
# 1893         NaN         NaN         NaN         NaN  ...          NaN
# 1894         NaN         NaN         NaN         NaN  ...          NaN
# 1895         NaN         NaN         NaN         NaN  ...          NaN
# 1896         NaN         NaN         NaN         NaN  ...          NaN
# 1897         NaN         NaN         NaN         NaN  ...          NaN
#
#       Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 1893          NaN          NaN          NaN          NaN          NaN
# 1894          NaN          NaN          NaN          NaN          NaN
# 1895          NaN          NaN          NaN          NaN          NaN
# 1896          NaN          NaN          NaN          NaN          NaN
# 1897          NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0             NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 1893          NaN          NaN          NaN          NaN
# 1894          NaN          NaN          NaN          NaN
# 1895          NaN          NaN          NaN          NaN
# 1896          NaN          NaN          NaN          NaN
# 1897          NaN          NaN          NaN          NaN
#
# [1898 rows x 26 columns]

# %% [markdown]
# # Let's plot the two spectra and see how they look like

# %%
plt.plot(Alloy_7022.Wavelength,Alloy_7022.Intensity)

# %%
plt.plot(Alloy_4043.Wavelength,Alloy_4043.Intensity)

# %% [markdown]
# # In Simple means , what we want to exactly do is , we want to see , which are disimlarities between two plot's , so that we can take them into consideration and then use it for distinguishing between Alloy 4043 and Alloy 7022
#
# Algo:-
#
# 1:- Get Peaks for Alloy 7022 , from that deduce wavelength
# 2:- Get Peaks for Alloy 4043 , from that deduce wavelength
# 3:- Compare the two wavelengths , and notice the disimilarities

# %% [markdown]
# # Getting Peak for Alloy 7022 [Using Peak Utils]

# %%
minimum_distance_7022 = 0  #Since , the Spectral Resolution of the Handheld LIBS Device is much smaller , We can keep this parameter as 0
threshold_7022 = 0 #looking for a value above 0.5% , so that Noise and  Peak with very low Intensities can be ignored 

Reference_Peak_7022 = indexes(Alloy_7022.Intensity , min_dist=minimum_distance_7022 , thres=threshold_7022) 
Reference_Peak_7022 #Return the indices in the form of the list
# Out:
# array([   3,   14,   36,   57,   78,  107,  127,  155,  192,  243,  312,
#         349,  421,  494,  525,  572,  663,  711,  792,  907,  979, 1091,
#        1182, 1268, 1351, 1445, 1642, 1726])

# %% [markdown]
# # Getting Peak for Alloy 4043 [Using Peak Utils]

# %%
minimum_distance_4043 = 0  #Since , the Spectral Resolution of the Handheld LIBS Device is much smaller , We can keep this parameter as 0
threshold_7022 = 0 #looking for a value above 0.5% , so that Noise and  Peak with very low Intensities can be ignored 

Reference_Peak_7022 = indexes(Alloy_7022.Intensity , min_dist=minimum_distance_7022 , thres=threshold_7022) 
Reference_Peak_7022 #Return the indices in the form of the list
