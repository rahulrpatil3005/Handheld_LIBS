# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import statistics
###############################################
from peakutils import indexes
from peakutils import baseline
from scipy.signal import find_peaks as fp
from scipy.signal import savgol_filter 
###############################################
from bokeh.plotting import figure , show

from bokeh.io import output_notebook
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ae3d5f2f-4c86-41f9-8667-33df3ff0e8a0">Loading BokehJS ...</span>
#     </div>

# %%
file_path1 = 'CR210LA-1.csv'
file_path2 = 'CR210LA-2.csv'
file_path3 = 'CR210LA-3.csv'
file_path4 = 'CR210LA-4.csv'
file_path5 = 'CR210LA-5.csv'
file_path6 = 'CR210LA-6.csv'
file_path7 = 'CR210LA-7.csv'
file_path8 = 'CR210LA-8.csv'

file_path9 = '1787.csv'
file_path10 = '1788.csv'
file_path11 = '1789.csv'
file_path12 = '1790.csv'




Sample_Spectra1 = pd.read_csv(file_path1)
Sample_Spectra2 = pd.read_csv(file_path2)
Sample_Spectra3 = pd.read_csv(file_path3)
Sample_Spectra4 = pd.read_csv(file_path4)
Sample_Spectra5 = pd.read_csv(file_path5)
Sample_Spectra6 = pd.read_csv(file_path6)
Sample_Spectra7 = pd.read_csv(file_path7)
Sample_Spectra8 = pd.read_csv(file_path8)
Sample_Spectra9 = pd.read_csv(file_path9)
Sample_Spectra10 = pd.read_csv(file_path10)
Sample_Spectra11 = pd.read_csv(file_path11)
Sample_Spectra12 = pd.read_csv(file_path12)



Sample_Spectra1 = Sample_Spectra1.rename({' intensity':'Intensities'},axis=1)
Sample_Spectra2 = Sample_Spectra2.rename({' intensity':'Intensities'},axis=1)
Sample_Spectra3 = Sample_Spectra3.rename({' intensity':'Intensities'},axis=1)
Sample_Spectra4 = Sample_Spectra4.rename({' intensity':'Intensities'},axis=1)
Sample_Spectra5 = Sample_Spectra5.rename({' intensity':'Intensities'},axis=1)
Sample_Spectra6 = Sample_Spectra6.rename({' intensity':'Intensities'},axis=1)
Sample_Spectra7 = Sample_Spectra7.rename({' intensity':'Intensities'},axis=1)
Sample_Spectra8 = Sample_Spectra8.rename({' intensity':'Intensities'},axis=1)

Sample_Spectra9 = Sample_Spectra9.rename({'intensity':'Intensities'},axis=1)
Sample_Spectra10 = Sample_Spectra10.rename({'intensity':'Intensities'},axis=1)
Sample_Spectra11 = Sample_Spectra11.rename({'intensity':'Intensities'},axis=1)
Sample_Spectra12 = Sample_Spectra12.rename({'intensity':'Intensities'},axis=1)



Sample_Spectra1


Sample_Spectra_Plot = figure(title = 'Raw Sample Spectra' , x_axis_label = 'Wavelength' , y_axis_label = 'Intensity')
Sample_Spectra_Plot.line(Sample_Spectra1.wavelength,Sample_Spectra1.Intensities  ,line_width = 2, color ="green" )
Sample_Spectra_Plot.line(Sample_Spectra11.wavelength,Sample_Spectra11.Intensities  ,line_width = 2, color ="red" )

Sample_Spectra_Plot.width = 1200
Sample_Spectra_Plot.height = 600

show (Sample_Spectra_Plot)
# Out:
#   <div id="d27a856a-8efd-4a09-84bb-45ef2cfc2e52" data-root-id="p1641" style="display: contents;"></div>
